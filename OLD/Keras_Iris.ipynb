# %% [markdown]
# # Machine Learning with Keras: The Python Deep Learning library
#
# Keras is a high level machine learning API, written in Python and runs on top of Tensorflow or Theano.
# Packages like Keras and Tensorflow make it much easier and more efficient to build machine learning models.
# This Notebook is a brief introduction to Keras, you can find the documentation [here.](https://keras.io/)
#
# First you need to install Tansorflow on your local machine. Open a command prompt and run the following:
#
# pip install --user tensorflow==1.12
#
# pip install –-user keras
#
# There is also a video of how to do this on Blackboard in the learning materials > python resources folder.
#
# Once your environment is set up first load and process the data as before...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical

# Read data from csv
iris = pd.read_csv("data/Iris.csv")
print(iris.head())

# Replace the species with 1,2 or 3 as appropriate
iris['Species'].replace(['Iris-setosa', 'Iris-virginica', 'Iris-versicolor'], [0, 1, 2], inplace=True)

# Get labels, flatten and encode to one-hot
columns = ['Species']
labels = pd.DataFrame(iris, columns=columns).to_numpy()
labels = labels.flatten()
labels = to_categorical(labels)

# Get Features
columns = ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth']
features = pd.DataFrame(iris, columns=columns).to_numpy()

# Split data to training and test data, 2/3 for training and 1/3 for testing
train_x, test_x, train_y, test_y = train_test_split(features, labels, test_size=0.33, random_state=2)
# Out:
#    Id  SepalLength  SepalWidth  PetalLength  PetalWidth      Species
# 0   1          5.1         3.5          1.4         0.2  Iris-setosa
# 1   2          4.9         3.0          1.4         0.2  Iris-setosa
# 2   3          4.7         3.2          1.3         0.2  Iris-setosa
# 3   4          4.6         3.1          1.5         0.2  Iris-setosa
# 4   5          5.0         3.6          1.4         0.2  Iris-setosa

# %% [markdown]
# Next we build the Keras model and we can train it with just one line of code...
#
# **Note:** Keras doesn't seem to play nicely with the sigmoid activation function so we will use ReLu.

# %%
from keras.models import Sequential 
from keras.layers import Dense, Dropout
from keras import optimizers

# Learning rate
learning_rate = 0.01

# Number of training epochs
num_epochs = 100

# Network architecture parameters
num_features = len(train_x[0])
num_classes = len(train_y[0])
num_hidden_nodes = 10

# With sequential we can just add layers to the network
model = Sequential()
model.add(Dense(num_hidden_nodes, input_dim=num_features, activation='relu'))
model.add(Dense(num_hidden_nodes, activation='relu'))
model.add(Dense(num_hidden_nodes, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))
sgd = optimizers.SGD(lr=learning_rate)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
model.summary()

# The fit function returns a dictionary of the training and evaluation losses and accuracies
metrics = model.fit(train_x, train_y, validation_data=(test_x, test_y), epochs=num_epochs, verbose=2)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_23 (Dense)             (None, 10)                50
# _________________________________________________________________
# dense_24 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_25 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_26 (Dense)             (None, 3)                 33
# =================================================================
# Total params: 303
# Trainable params: 303
# Non-trainable params: 0
# _________________________________________________________________
# Train on 100 samples, validate on 50 samples
# Epoch 1/100
#  - 0s - loss: 1.3536 - acc: 0.3400 - val_loss: 1.3077 - val_acc: 0.3200
# Epoch 2/100
#  - 0s - loss: 1.2454 - acc: 0.3400 - val_loss: 1.1988 - val_acc: 0.3200
# Epoch 3/100
#  - 0s - loss: 1.1536 - acc: 0.3400 - val_loss: 1.0923 - val_acc: 0.3200
# Epoch 4/100
#  - 0s - loss: 1.0731 - acc: 0.3400 - val_loss: 1.0370 - val_acc: 0.3200
# Epoch 5/100
#  - 0s - loss: 1.0146 - acc: 0.3400 - val_loss: 1.0043 - val_acc: 0.3200
# Epoch 6/100
#  - 0s - loss: 0.9815 - acc: 0.3400 - val_loss: 0.9733 - val_acc: 0.3200
# Epoch 7/100
#  - 0s - loss: 0.9516 - acc: 0.3400 - val_loss: 0.9452 - val_acc: 0.3800
# Epoch 8/100
#  - 0s - loss: 0.9249 - acc: 0.4200 - val_loss: 0.9188 - val_acc: 0.8800
# Epoch 9/100
#  - 0s - loss: 0.9015 - acc: 0.9100 - val_loss: 0.8918 - val_acc: 0.8000
# Epoch 10/100
#  - 0s - loss: 0.8736 - acc: 0.8400 - val_loss: 0.8576 - val_acc: 0.7200
# Epoch 11/100
#  - 0s - loss: 0.8494 - acc: 0.7200 - val_loss: 0.8277 - val_acc: 0.6800
# Epoch 12/100
#  - 0s - loss: 0.8311 - acc: 0.6700 - val_loss: 0.8149 - val_acc: 0.8600
# Epoch 13/100
#  - 0s - loss: 0.8067 - acc: 0.7600 - val_loss: 0.7845 - val_acc: 0.8000
# Epoch 14/100
#  - 0s - loss: 0.7839 - acc: 0.8100 - val_loss: 0.7851 - val_acc: 0.6800
# Epoch 15/100
#  - 0s - loss: 0.7681 - acc: 0.6600 - val_loss: 0.7422 - val_acc: 0.6800
# Epoch 16/100
#  - 0s - loss: 0.7461 - acc: 0.6600 - val_loss: 0.7541 - val_acc: 0.6800
# Epoch 17/100
#  - 0s - loss: 0.7359 - acc: 0.6600 - val_loss: 0.7166 - val_acc: 0.6800
# Epoch 18/100
#  - 0s - loss: 0.7095 - acc: 0.6600 - val_loss: 0.6924 - val_acc: 0.6800
# Epoch 19/100
#  - 0s - loss: 0.6900 - acc: 0.6600 - val_loss: 0.6724 - val_acc: 0.6800
# Epoch 20/100
#  - 0s - loss: 0.6741 - acc: 0.6600 - val_loss: 0.6422 - val_acc: 0.7600
# Epoch 21/100
#  - 0s - loss: 0.6573 - acc: 0.7300 - val_loss: 0.6276 - val_acc: 0.8000
# Epoch 22/100
#  - 0s - loss: 0.6400 - acc: 0.7800 - val_loss: 0.6116 - val_acc: 0.9000
# Epoch 23/100
#  - 0s - loss: 0.6270 - acc: 0.8600 - val_loss: 0.5947 - val_acc: 0.7400
# Epoch 24/100
#  - 0s - loss: 0.6130 - acc: 0.7000 - val_loss: 0.5962 - val_acc: 0.6800
# Epoch 25/100
#  - 0s - loss: 0.6016 - acc: 0.6600 - val_loss: 0.5784 - val_acc: 0.7000
# Epoch 26/100
#  - 0s - loss: 0.5888 - acc: 0.6800 - val_loss: 0.5688 - val_acc: 0.7000
# Epoch 27/100
#  - 0s - loss: 0.5775 - acc: 0.6800 - val_loss: 0.5497 - val_acc: 0.7600
# Epoch 28/100
#  - 0s - loss: 0.5669 - acc: 0.7000 - val_loss: 0.5349 - val_acc: 0.8200
# Epoch 29/100
#  - 0s - loss: 0.5591 - acc: 0.8600 - val_loss: 0.5276 - val_acc: 0.7800
# Epoch 30/100
#  - 0s - loss: 0.5459 - acc: 0.7500 - val_loss: 0.5144 - val_acc: 0.9800
# Epoch 31/100
#  - 0s - loss: 0.5388 - acc: 0.9100 - val_loss: 0.5057 - val_acc: 0.8600
# Epoch 32/100
#  - 0s - loss: 0.5306 - acc: 0.8900 - val_loss: 0.5043 - val_acc: 0.7800
# Epoch 33/100
#  - 0s - loss: 0.5231 - acc: 0.8700 - val_loss: 0.5088 - val_acc: 0.6800
# Epoch 34/100
#  - 0s - loss: 0.5222 - acc: 0.7100 - val_loss: 0.4857 - val_acc: 0.7800
# Epoch 35/100
#  - 0s - loss: 0.5072 - acc: 0.8300 - val_loss: 0.4747 - val_acc: 0.9600
# Epoch 36/100
#  - 0s - loss: 0.5032 - acc: 0.9300 - val_loss: 0.4655 - val_acc: 0.9600
# Epoch 37/100
#  - 0s - loss: 0.5005 - acc: 0.9400 - val_loss: 0.4628 - val_acc: 0.8400
# Epoch 38/100
#  - 0s - loss: 0.4872 - acc: 0.8700 - val_loss: 0.4601 - val_acc: 0.9800
# Epoch 39/100
#  - 0s - loss: 0.4848 - acc: 0.9200 - val_loss: 0.4556 - val_acc: 0.9000
# Epoch 40/100
#  - 0s - loss: 0.4882 - acc: 0.8900 - val_loss: 0.4399 - val_acc: 0.9600
# Epoch 41/100
#  - 0s - loss: 0.4758 - acc: 0.9300 - val_loss: 0.4397 - val_acc: 0.8000
# Epoch 42/100
#  - 0s - loss: 0.4635 - acc: 0.8600 - val_loss: 0.4323 - val_acc: 0.9200
# Epoch 43/100
#  - 0s - loss: 0.4656 - acc: 0.8800 - val_loss: 0.4240 - val_acc: 0.9400
# Epoch 44/100
#  - 0s - loss: 0.4645 - acc: 0.9100 - val_loss: 0.4280 - val_acc: 0.8400
# Epoch 45/100
#  - 0s - loss: 0.4623 - acc: 0.8900 - val_loss: 0.4242 - val_acc: 0.7800
# Epoch 46/100
#  - 0s - loss: 0.4467 - acc: 0.8800 - val_loss: 0.4126 - val_acc: 0.8400
# Epoch 47/100
#  - 0s - loss: 0.4400 - acc: 0.9100 - val_loss: 0.4194 - val_acc: 0.7600
# Epoch 48/100
#  - 0s - loss: 0.4396 - acc: 0.7900 - val_loss: 0.4194 - val_acc: 0.7400
# Epoch 49/100
#  - 0s - loss: 0.4370 - acc: 0.7700 - val_loss: 0.4045 - val_acc: 0.7800
# Epoch 50/100
#  - 0s - loss: 0.4311 - acc: 0.8200 - val_loss: 0.3923 - val_acc: 0.8400
# Epoch 51/100
#  - 0s - loss: 0.4234 - acc: 0.9100 - val_loss: 0.4064 - val_acc: 0.7600
# Epoch 52/100
#  - 0s - loss: 0.4241 - acc: 0.7900 - val_loss: 0.4015 - val_acc: 0.7600
# Epoch 53/100
#  - 0s - loss: 0.4222 - acc: 0.8300 - val_loss: 0.4166 - val_acc: 0.7000
# Epoch 54/100
#  - 0s - loss: 0.4258 - acc: 0.7600 - val_loss: 0.4025 - val_acc: 0.7400
# Epoch 55/100
#  - 0s - loss: 0.4174 - acc: 0.7600 - val_loss: 0.4040 - val_acc: 0.7200
# Epoch 56/100
#  - 0s - loss: 0.4159 - acc: 0.7300 - val_loss: 0.3768 - val_acc: 0.7800
# Epoch 57/100
#  - 0s - loss: 0.4038 - acc: 0.8900 - val_loss: 0.3755 - val_acc: 0.7800
# Epoch 58/100
#  - 0s - loss: 0.3971 - acc: 0.8800 - val_loss: 0.3569 - val_acc: 0.9800
# Epoch 59/100
#  - 0s - loss: 0.3905 - acc: 0.9300 - val_loss: 0.3712 - val_acc: 0.8600
# Epoch 60/100
#  - 0s - loss: 0.4087 - acc: 0.8900 - val_loss: 0.3524 - val_acc: 0.9600
# Epoch 61/100
#  - 0s - loss: 0.3829 - acc: 0.9100 - val_loss: 0.3527 - val_acc: 0.9200
# Epoch 62/100
#  - 0s - loss: 0.3869 - acc: 0.9300 - val_loss: 0.3450 - val_acc: 0.9600
# Epoch 63/100
#  - 0s - loss: 0.3870 - acc: 0.9200 - val_loss: 0.3424 - val_acc: 0.9600
# Epoch 64/100
#  - 0s - loss: 0.3767 - acc: 0.9200 - val_loss: 0.3391 - val_acc: 0.9600
# Epoch 65/100
#  - 0s - loss: 0.3676 - acc: 0.9100 - val_loss: 0.3370 - val_acc: 0.9200
# Epoch 66/100
#  - 0s - loss: 0.3775 - acc: 0.9000 - val_loss: 0.3309 - val_acc: 0.9800
# Epoch 67/100
#  - 0s - loss: 0.3581 - acc: 0.9200 - val_loss: 0.3235 - val_acc: 0.9600
# Epoch 68/100
#  - 0s - loss: 0.3600 - acc: 0.9500 - val_loss: 0.3212 - val_acc: 0.9400
# Epoch 69/100
#  - 0s - loss: 0.3588 - acc: 0.9500 - val_loss: 0.3179 - val_acc: 0.9600
# Epoch 70/100
#  - 0s - loss: 0.3530 - acc: 0.9200 - val_loss: 0.3111 - val_acc: 0.9600
# Epoch 71/100
#  - 0s - loss: 0.3502 - acc: 0.9400 - val_loss: 0.3098 - val_acc: 0.9800
# Epoch 72/100
#  - 0s - loss: 0.3415 - acc: 0.9500 - val_loss: 0.3138 - val_acc: 0.9200
# Epoch 73/100
#  - 0s - loss: 0.3429 - acc: 0.9300 - val_loss: 0.3073 - val_acc: 0.9600
# Epoch 74/100
#  - 0s - loss: 0.3354 - acc: 0.9100 - val_loss: 0.3081 - val_acc: 0.9200
# Epoch 75/100
#  - 0s - loss: 0.3406 - acc: 0.9500 - val_loss: 0.2965 - val_acc: 0.9800
# Epoch 76/100
#  - 0s - loss: 0.3260 - acc: 0.9200 - val_loss: 0.3629 - val_acc: 0.8000
# Epoch 77/100
#  - 0s - loss: 0.3734 - acc: 0.8600 - val_loss: 0.2970 - val_acc: 0.9200
# Epoch 78/100
#  - 0s - loss: 0.3277 - acc: 0.9100 - val_loss: 0.2849 - val_acc: 0.9600
# Epoch 79/100
#  - 0s - loss: 0.3212 - acc: 0.9500 - val_loss: 0.2873 - val_acc: 0.9400
# Epoch 80/100
#  - 0s - loss: 0.3233 - acc: 0.9300 - val_loss: 0.2948 - val_acc: 0.9200
# Epoch 81/100
#  - 0s - loss: 0.3198 - acc: 0.9300 - val_loss: 0.2828 - val_acc: 0.9400
# Epoch 82/100
#  - 0s - loss: 0.3098 - acc: 0.9400 - val_loss: 0.2785 - val_acc: 0.9800
# Epoch 83/100
#  - 0s - loss: 0.3078 - acc: 0.9100 - val_loss: 0.2767 - val_acc: 0.9600
# Epoch 84/100
#  - 0s - loss: 0.2979 - acc: 0.9200 - val_loss: 0.2756 - val_acc: 0.9600
# Epoch 85/100
#  - 0s - loss: 0.2965 - acc: 0.9400 - val_loss: 0.3374 - val_acc: 0.7800
# Epoch 86/100
#  - 0s - loss: 0.3238 - acc: 0.8600 - val_loss: 0.2576 - val_acc: 0.9600
# Epoch 87/100
#  - 0s - loss: 0.2870 - acc: 0.9400 - val_loss: 0.2543 - val_acc: 0.9600
# Epoch 88/100
#  - 0s - loss: 0.2828 - acc: 0.9700 - val_loss: 0.2662 - val_acc: 0.9200
# Epoch 89/100
#  - 0s - loss: 0.2882 - acc: 0.9500 - val_loss: 0.2503 - val_acc: 0.9600
# Epoch 90/100
#  - 0s - loss: 0.2774 - acc: 0.9700 - val_loss: 0.2598 - val_acc: 0.9600
# Epoch 91/100
#  - 0s - loss: 0.2771 - acc: 0.9400 - val_loss: 0.2620 - val_acc: 0.9600
# Epoch 92/100
#  - 0s - loss: 0.2784 - acc: 0.9300 - val_loss: 0.2398 - val_acc: 0.9600
# Epoch 93/100
#  - 0s - loss: 0.2669 - acc: 0.9500 - val_loss: 0.2459 - val_acc: 0.9400
# Epoch 94/100
#  - 0s - loss: 0.2696 - acc: 0.9400 - val_loss: 0.2768 - val_acc: 0.8800
# Epoch 95/100
#  - 0s - loss: 0.2818 - acc: 0.9300 - val_loss: 0.2393 - val_acc: 0.9800
# Epoch 96/100
#  - 0s - loss: 0.2588 - acc: 0.9500 - val_loss: 0.2312 - val_acc: 0.9400
# Epoch 97/100
#  - 0s - loss: 0.2566 - acc: 0.9400 - val_loss: 0.2753 - val_acc: 0.8800
# Epoch 98/100
#  - 0s - loss: 0.2924 - acc: 0.8900 - val_loss: 0.2379 - val_acc: 0.9600
# Epoch 99/100
#  - 0s - loss: 0.2489 - acc: 0.9200 - val_loss: 0.2652 - val_acc: 0.8800
# Epoch 100/100
#  - 0s - loss: 0.2633 - acc: 0.9500 - val_loss: 0.2170 - val_acc: 0.9600

# %% [markdown]
# Evaluate the model
#
# If we had a 3rd evaluation set of unseen data we could evaluate it here.
# Instead we will just use the same test set from before.

# %%
# Plot the error chart
plt.plot(metrics.history['loss'])
plt.plot(metrics.history['val_loss'])
plt.xlabel('Epochs')
plt.ylabel('Error')
plt.show()

# Plot the accuracy chart
plt.plot(metrics.history['acc'])
plt.plot(metrics.history['val_acc'])
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()

eval_metrics = model.evaluate(test_x, test_y)
print("Evaluation: Loss=" + str(round(eval_metrics[0], 3)) + " Accuracy=" + str(round(eval_metrics[1], 3)))
# Out:
# 50/50 [==============================] - 0s 40us/step
# Evaluation: Loss=0.217 Accuracy=0.96
